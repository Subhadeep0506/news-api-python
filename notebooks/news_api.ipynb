# %%
import os
import requests
import http.client, urllib.parse

from dotenv import load_dotenv
from pprint import pprint

load_dotenv()
# Out:
# True

# %% [markdown]
# ### The news api

# %%
conn = http.client.HTTPSConnection("api.thenewsapi.com")
# general | science | sports | business | health | entertainment | tech | politics | food | trave
params = urllib.parse.urlencode(
    {
        "api_token": os.environ["THE_NEWS_API_KEY"],
        "categories": "business,tech,sports",
        "limit": 10,
        "language": "en",
        "locale": "in",
        "search": "cricket",
    }
)

# %%
conn.request("GET", "/v1/news/all?{}".format(params))

res = conn.getresponse()
data = res.read()

# %%
print(data.decode("utf-8"))
# Out:
# {"warnings":["limit is higher than your plan allows"],"meta":{"found":23561,"returned":3,"limit":3,"page":1},"data":[{"uuid":"8084e41d-dcfc-454b-ae74-714a2d453bcf","title":"Cricket Adds New Affordable Phones Under Cricket Brand","description":"Cricket has launched two new affordable 4G phones as white-label models (under its own brand). The Cricket Icon 6 replaces the Icon 5, and the Cricket Debut S3 ...","keywords":"","snippet":"Cricket Adds New Affordable Phones Under Cricket Brand\n\nArticle Comments\n\nToday, 11:36 AM by Rich Brome\n\nCricket has launched two new affordable 4G phones as wh...","url":"https:\/\/www.phonescoop.com\/articles\/article.php?a=23347","image_url":"https:\/\/www.phonescoop.com\/img\/a\/f\/23347_600_a_d11878c3dc20c2ecc22b6ff8dc0d55e1.jpg","language":"en","published_at":"2024-09-09T16:36:46.000000Z","source":"phonescoop.com","categories":["tech"],"relevance_score":24.361967},{"uuid":"d3af9ba9-2ab1-4795-a062-3c15eb35080d","title":"Equity in Cricket report: D
# ...

# %%
{
    "meta": {"found": 23305, "returned": 3, "limit": 3, "page": 1},
    "data": [
        {
            "uuid": "8084e41d-dcfc-454b-ae74-714a2d453bcf",
            "title": "Cricket Adds New Affordable Phones Under Cricket Brand",
            "description": "Cricket has launched two new affordable 4G phones as white-label models (under its own brand). The Cricket Icon 6 replaces the Icon 5, and the Cricket Debut S3 ...",
            "keywords": "",
            "snippet": "Cricket Adds New Affordable Phones Under Cricket Brand\n\nArticle Comments\n\nToday, 11:36 AM by Rich Brome\n\nCricket has launched two new affordable 4G phones as wh...",
            "url": "https:\/\/www.phonescoop.com\/articles\/article.php?a=23347",
            "image_url": "https:\/\/www.phonescoop.com\/img\/a\/f\/23347_600_a_d11878c3dc20c2ecc22b6ff8dc0d55e1.jpg",
            "language": "en",
            "published_at": "2024-09-09T16:36:46.000000Z",
            "source": "phonescoop.com",
            "categories": ["tech"],
            "relevance_score": 24.368027,
        },
        {
            "uuid": "d3af9ba9-2ab1-4795-a062-3c15eb35080d",
            "title": "Equity in Cricket report: Discrimination 'widespread' in English cricket",
            "description": 'Racism, sexism, classism and elitism is "widespread" in English and Welsh cricket, according to a long-awaited independent report.',
            "keywords": "",
            "snippet": "Last updated on .From the section Cricket\n\nThe Independent Commission for Equity in Cricket received more than 4,000 responses to its call for evidence\n\nRacism,...",
            "url": "https:\/\/www.bbc.co.uk\/sport\/cricket\/66022949",
            "image_url": "https:\/\/ichef.bbci.co.uk\/live-experience\/cps\/624\/cpsprodpb\/265D\/production\/_130212890_cricket.jpg",
            "language": "en",
            "published_at": "2023-06-26T23:01:16.000000Z",
            "source": "bbc.co.uk",
            "categories": ["sports"],
            "relevance_score": 23.632753,
        },
        {
            "uuid": "18c45369-2ebd-49ba-b115-82fdde68b06e",
            "title": "Revolutionizing Fantasy Cricket: The Rise of Fantasy Cricket App Development Companies",
            "description": "➤Introduction: Cricket, often dubbed as a religion in countries like India, has witnessed a significant transformation with the advent of fantasy cricket apps...",
            "keywords": "",
            "snippet": "Revolutionizing Fantasy Cricket: The Rise of Fantasy Cricket App Development Companies Johnxaavier · Follow 2 min read · Just now Just now -- Listen Share\n\n?...",
            "url": "https:\/\/medium.com\/@johnxaavier\/revolutionizing-fantasy-cricket-the-rise-of-fantasy-cricket-app-development-companies-4d55b0de98ad",
            "image_url": "https:\/\/miro.medium.com\/v2\/1*m-R_BkNf1Qjr1YbyOIJY2w.png",
            "language": "en",
            "published_at": "2024-04-09T10:55:05.000000Z",
            "source": "medium.com",
            "categories": ["tech", "science", "business"],
            "relevance_score": 23.513073,
        },
    ],
}

# %% [markdown]
# ### news api

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key="NEWS_API_API_KEY")

# %%
# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(
    q="openai",
    # sources="bbc-news,the-verge",
    category="business",
    language="en",
    country="us",
)

print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'the-wall-street-journal', 'name': 'The Wall Street Journal'}, 'author': 'Theo Francis, Berber Jin, Tom Dotan', 'title': 'OpenAI’s Complex Path to Becoming a For-Profit Company - The Wall Street Journal', 'description': 'Converting from a nonprofit happens rarely, especially for organizations this wealthy. OpenAI has two years to do so.', 'url': 'https://www.wsj.com/tech/ai/openais-complex-path-to-becoming-a-for-profit-company-bad21a42', 'urlToImage': 'https://images.wsj.net/im-58829845/social', 'publishedAt': '2024-09-29T04:01:00Z', 'content': 'OpenAIs plan to convert to a \r\nfor-profit company is meant to simplify the worlds leading artificial-intelligence startup. Making that happen will be enormously complex.\xa0The ChatGPT maker is in the m… [+579 chars]'}]}

# %%
{
    "status": "ok",
    "totalResults": 1,
    "articles": [
        {
            "source": {
                "id": "the-wall-street-journal",
                "name": "The Wall Street Journal",
            },
            "author": "Theo Francis, Berber Jin, Tom Dotan",
            "title": "OpenAI’s Complex Path to Becoming a For-Profit Company - The Wall Street Journal",
            "description": "Converting from a nonprofit happens rarely, especially for organizations this wealthy. OpenAI has two years to do so.",
            "url": "https://www.wsj.com/tech/ai/openais-complex-path-to-becoming-a-for-profit-company-bad21a42",
            "urlToImage": "https://images.wsj.net/im-58829845/social",
            "publishedAt": "2024-09-29T04:01:00Z",
            "content": "OpenAIs plan to convert to a \r\nfor-profit company is meant to simplify the worlds leading artificial-intelligence startup. Making that happen will be enormously complex.\xa0The ChatGPT maker is in the m… [+579 chars]",
        }
    ],
}

# %%
# /v2/everything
all_articles = newsapi.get_everything(
    q="openai",
    sources="bbc-news,the-verge",
    domains="bbc.co.uk,techcrunch.com",
    # from_param="2017-12-01",
    # to="2017-12-12",
    language="en",
    sort_by="relevancy",
    page=2,
)

print(all_articles)
# Out:
# {'status': 'ok', 'totalResults': 128, 'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'}, 'author': 'Ingrid Lunden', 'title': "Elon Musk's Brazil battle wages on | TechCrunch", 'description': "Is Elon's rumble in the Amazonian jungle on course for a technical knockout? Over the weekend, the Brazilian high court voted to\xa0uphold a ban on X that", 'url': 'https://techcrunch.com/2024/09/03/elon-musks-brazil-battle-wages-on/', 'urlToImage': 'https://techcrunch.com/wp-content/uploads/2024/08/Elon-Musk.jpg?resize=1200,800', 'publishedAt': '2024-09-03T12:11:58Z', 'content': 'Is Elon’s rumble in the Amazonian jungle on course for a technical knockout? Over the weekend, the Brazilian high court voted to\xa0uphold a ban on X that another judge issued the week before for failin… [+5244 chars]'}, {'source': {'id': 'techcrunch', 'name': 'TechCrunch'}, 'author': 'Aisha Malik', 'title': 'Snap is introducing an AI video generation tool for creators | TechCrunch', 'description': 'At
# ...

# %%
# /v2/top-headlines/sources
sources = newsapi.get_sources()

pprint(sources)
# Out:
# {'sources': [{'category': 'general',
#               'country': 'us',
#               'description': 'Your trusted source for breaking news, analysis, '
#                              'exclusive interviews, headlines, and videos at '
#                              'ABCNews.com.',
#               'id': 'abc-news',
#               'language': 'en',
#               'name': 'ABC News',
#               'url': 'https://abcnews.go.com'},
#              {'category': 'general',
#               'country': 'au',
#               'description': "Australia's most trusted source of local, "
#                              'national and world news. Comprehensive, '
#                              'independent, in-depth analysis, the latest '
#                              'business, sport, weather and more.',
#               'id': 'abc-news-au',
#               'language': 'en',
#               'name': 'ABC News (AU)',
#               'url': 'https://www.abc.net.au/news'},
# ...

# %%
from newsdataapi import NewsDataApiClient

# %%
api = NewsDataApiClient(apikey="NEWSDATA_API_KEY")
response = api.news_api(q="openai", country="us")
print(response)
# Out:
# /tmp/ipykernel_154373/3216544036.py:2: DeprecationWarning: This method is deprecated and will be removed in upcoming updates, Instead use latest_api()
#   response = api.news_api(q="openai", country="us")
# ...

# %%
{
    "status": "success",
    "totalResults": 203,
    "results": [
        {
            "article_id": "23865398b77bc3f63a8ced1e880c9850",
            "title": "Why OpenAI Is Trying to Raise So Much Money?",
            "link": "https://news.knowledia.com/US/en/articles/why-openai-is-trying-to-raise-so-much-money-2983ebbb1a20425c93edbb2910f93c512bcce1a9?source=rss",
            "keywords": None,
            "creator": None,
            "video_url": None,
            "description": "The San Francisco A.I. start-up believes there is not enough computing power on Earth to build the artificial intelligence it wants to create. - www.nytimes.com",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-02 02:09:12",
            "pubDateTZ": "UTC",
            "image_url": "https://static01.nyt.com/images/2024/09/27/business/00a-chips-explainer-SUB/00a-chips-explainer-SUB-videoSixteenByNineJumbo1600.png",
            "source_id": "knowledia",
            "source_priority": 167779,
            "source_name": "Knowledia News",
            "source_url": "http://news.knowledia.com",
            "source_icon": "https://i.bytvi.com/domain_icons/knowledia.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["top"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": True,
        },
        {
            "article_id": "1228f8b89c17d9fff327e8cf3cb26d75",
            "title": "Could bad actors use AI to create a deadly pandemic? | Andrew Makridis",
            "link": "https://helenair.com/opinion/column/andrew-makridis-ai-deadly-pandemic-cia/article_aa1e332b-68e4-5693-881f-715133c56e1b.html",
            "keywords": None,
            "creator": ["ANDREW MAKRIDIS"],
            "video_url": None,
            "description": 'The best way to counter "bad AI" isn\'t "no AI" — it\'s "good AI."',
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-02 01:45:00",
            "pubDateTZ": "UTC",
            "image_url": "https://bloximages.chicago2.vip.townnews.com/helenair.com/content/tncms/assets/v3/editorial/a/a1/aa1e332b-68e4-5693-881f-715133c56e1b/66fca5b6736ac.preview.jpg?crop=1842%2C967%2C0%2C78&order=crop%2Cresize&resize=1200%2C630",
            "source_id": "helenair",
            "source_priority": 36771,
            "source_name": "Helenair",
            "source_url": "https://helenair.com",
            "source_icon": "https://i.bytvi.com/domain_icons/helenair.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["politics"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": True,
        },
        {
            "article_id": "f8eebb74267ea5d6b6ee864cf6426c2e",
            "title": "Could bad actors use AI to create a deadly pandemic? | Andrew Makridis",
            "link": "https://missoulian.com/opinion/column/andrew-makridis-ai-deadly-pandemic-cia/article_24979200-7f3c-11ef-9bbe-fba5f05f8505.html",
            "keywords": None,
            "creator": None,
            "video_url": None,
            "description": 'The best way to counter "bad AI" isn\'t "no AI" — it\'s "good AI."',
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-02 01:45:00",
            "pubDateTZ": "UTC",
            "image_url": None,
            "source_id": "missoulian",
            "source_priority": 26659,
            "source_name": "Missoulian",
            "source_url": "https://missoulian.com",
            "source_icon": "https://i.bytvi.com/domain_icons/missoulian.jpg",
            "language": "english",
            "country": ["united states of america"],
            "category": ["top"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
        {
            "article_id": "485eb4f7410ac443516ec2678e4a3229",
            "title": "OpenAI Opens New AI Voice Capability to Third-Party Developers",
            "link": "https://www.pymnts.com/artificial-intelligence-2/2024/openai-opens-new-ai-voice-capability-to-third-party-developers/",
            "keywords": [
                "voice assistant",
                "voice ai",
                "openai",
                "chatgpt",
                "ai",
                "what's hot",
                "apis",
                "artificial intelligence",
                "generative ai",
                "news",
                "pymnts news",
                "genai",
            ],
            "creator": ["PYMNTS"],
            "video_url": None,
            "description": "OpenAI is expanding access to its real-time voice assistant technology, allowing businesses and developers to integrate the artificial intelligence (AI)-powered tool into their own applications, Bloomberg reported. This move is set to broaden the reach of realistic spoken AI interactions across a wide range of tasks and industries. The new feature, which resembles the voice [...]The post OpenAI Opens New AI Voice Capability to Third-Party Developers appeared first on PYMNTS.com.",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-02 01:24:57",
            "pubDateTZ": "UTC",
            "image_url": "https://www.pymnts.com/wp-content/uploads/2024/10/OpenAI-voice-AI.jpg",
            "source_id": "pymnts",
            "source_priority": 12704,
            "source_name": "Pymnts",
            "source_url": "https://www.pymnts.com",
            "source_icon": "https://i.bytvi.com/domain_icons/pymnts.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["business"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
        {
            "article_id": "36b86cbce13c51104f536e1304cf6bd3",
            "title": "Santa Fe Public Schools embraces artificial intelligence as a 'thought partner' for students",
            "link": "https://www.santafenewmexican.com/news/education/santa-fe-public-schools-embraces-artificial-intelligence-as-a-thought-partner-for-students/article_c77b1770-7c1d-11ef-90b8-d79918fe772e.html",
            "keywords": None,
            "creator": None,
            "video_url": None,
            "description": "The district unveiled a plan to guide teachers on AI the classroom, including providing students with AI tutoring software.",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-02 01:00:00",
            "pubDateTZ": "UTC",
            "image_url": "https://bloximages.newyork1.vip.townnews.com/santafenewmexican.com/content/tncms/assets/v3/editorial/0/8b/08bd86e0-34bc-11ef-9d31-7f8295e47c09/65fdaec51fffb.image.jpg?resize=300%2C184",
            "source_id": "santafenewmexican",
            "source_priority": 21864,
            "source_name": "Santa Fe New Mexican Homepage | Santa Fe New Mexic",
            "source_url": "https://www.santafenewmexican.com",
            "source_icon": "https://i.bytvi.com/domain_icons/santafenewmexican.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["education"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
        {
            "article_id": "7599f6730c5caa281d072edc4124d2a0",
            "title": "OpenAI wants all your apps to talk in its expressive AI voices - The Washington Post",
            "link": "https://news.google.com/rss/articles/CBMikgFBVV95cUxOa1VhNzJBczBOM1V5TjVMMW8yWGcyNGNURWdHNWF1cDZXd0x6TjlXVnctbFl2QmVtN2RzWWVxeEllUENXRVRyY0tOS0x5VFFsOWM1ZU9BMGZkRHJtYi12MTJVcTQ0aXpXeTM3d0VrNGcxYVhoSnlmNUItaHpYZ2pzMFhPcnJXdGNsUzRrcVdwSERWdw?oc=5",
            "keywords": None,
            "creator": None,
            "video_url": None,
            "description": "OpenAI wants all your apps to talk in its expressive AI voices The Washington PostOpenAI Just Announced 4 New AI Features and They’re Available Now Inc.OpenAI introduces new tools to fast-track building of AI voice assistants ReutersOpenAI’s DevDay brings Realtime API and other treats for AI app developers TechCrunchOpenAI just launched advanced voice mode for audio chats with ChatGPT. Here's how to use it CNBC",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-02 00:15:00",
            "pubDateTZ": "UTC",
            "image_url": None,
            "source_id": "google",
            "source_priority": 14,
            "source_name": "Google News",
            "source_url": "https://news.google.com",
            "source_icon": "https://i.bytvi.com/domain_icons/google.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["technology"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
        {
            "article_id": "8d3c070527aaa01241b426b20f8624e2",
            "title": "Where's the AI Revenue? Plus, Will the Trillion-Dollar AI Gamble Pay Off?",
            "link": "https://hackernoon.com/wheres-the-ai-revenue-plus-will-the-trillion-dollar-ai-gamble-pay-off?source=rss",
            "keywords": [
                "future-of-ai",
                "ai-risks",
                "ai-gold-rush",
                "ai-gamble",
                "artificial-intelligence",
                "ai-economic-impact",
                "goldman-sachs-ai-opinion",
                "ai-profits",
            ],
            "creator": ["Renjit Philip"],
            "video_url": None,
            "description": "Tech companies are set to spend over $1 trillion on AI in the next few years. The report includes views from experts who are both hopeful and doubtful about AI's economic potential.",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-01 23:53:05",
            "pubDateTZ": "UTC",
            "image_url": "https://hackernoon.com/https://cdn.hackernoon.com/images/AVjFr77HYCX0MsvFuE0rftOItUx1-no239lc.png",
            "source_id": "hackernoon",
            "source_priority": 6723,
            "source_name": "Hackernoon",
            "source_url": "https://hackernoon.com",
            "source_icon": "https://i.bytvi.com/domain_icons/hackernoon.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["technology"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
        {
            "article_id": "78511dafdd94650ff92aeaedd06ae804",
            "title": "As AI Growth Explodes—Will SaaS Come Crashing Down?",
            "link": "https://www.forbes.com/sites/danielnewman/2024/10/01/as-ai-growth-explodes-will-saas-come-crashing-down/",
            "keywords": [
                "/ai",
                "standard",
                "innovation",
                "cmo network",
                "/innovation",
                "ai",
                "/leadership",
                "leadership",
                "/cmo-network",
            ],
            "creator": ["", "Daniel Newman, Contributor"],
            "video_url": None,
            "description": "As software gets more commoditized in the AI era, speculation has grown about the future of SaaS and enterprise software.",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-01 23:48:32",
            "pubDateTZ": "UTC",
            "image_url": "https://imageio.forbes.com/specials-images/imageserve/66fc85ce59a145641386be50/0x0.jpg?width=960",
            "source_id": "forbes",
            "source_priority": 154,
            "source_name": "Forbes",
            "source_url": "https://www.forbes.com",
            "source_icon": "https://i.bytvi.com/domain_icons/forbes.png",
            "language": "english",
            "country": ["united states of america"],
            "category": ["technology"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
        {
            "article_id": "d3a944a9c756bb7f72008fdfcf26390f",
            "title": "Por qué Microsoft intenta convertir su chatbot de inteligencia artificial en un amigo digital",
            "link": "https://noticiasya.com/2024/10/01/por-que-microsoft-intenta-convertir-chatbot-inteligencia-artificial-amigo-digital-trax/",
            "keywords": ["noticias nacionales"],
            "creator": [""],
            "video_url": None,
            "description": "Nueva York (CNN) — Los chatbots de inteligencia artificial se han presentado como herramientas de productividad para los consumidores: pueden ayudarte a planificar un viaje, por ejemplo, o aconsejarte sobre cómo escribir un correo electrónico difícil a tu casero. Pero a menudo suenan rebuscados, extrañamente testarudos o simplemente raros. Y a pesar de la proliferación de [...]The post Por qué Microsoft intenta convertir su chatbot de inteligencia artificial en un amigo digital appeared first on Noticias.",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-01 23:03:40",
            "pubDateTZ": "UTC",
            "image_url": None,
            "source_id": "noticiasyanacional",
            "source_priority": 548462,
            "source_name": "Noticiasyanacional",
            "source_url": "https://noticiasya.com/nacional",
            "source_icon": "https://i.bytvi.com/domain_icons/noticiasyanacional.jpg",
            "language": "spanish",
            "country": ["united states of america"],
            "category": ["top"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": True,
        },
        {
            "article_id": "dc1efe479195c73796ae3897bc7bfb0f",
            "title": "Nvidia just dropped a bombshell: Its new AI model is open, massive, and ready to rival GPT-4",
            "link": "https://venturebeat.com/ai/nvidia-just-dropped-a-bombshell-its-new-ai-model-is-open-massive-and-ready-to-rival-gpt-4/",
            "keywords": [
                "conversational ai",
                "nvlm-d-72b",
                "nvidia",
                "gpt-4 competitor",
                "ai model open-source",
                "data infrastructure",
                "nvidia ai innovation",
                "open-source ai model",
                "ai, ml and deep learning",
                "category-/science/computer science",
                "data management",
                "ai benchmarking 2024",
                "nvidia nvlm 1.0",
                "nvidia vs google ai",
                "nvidia ai release",
                "nvlm 1.0",
                "category-/computers & electronics",
                "data science",
                "vision-language ai",
                "ai research breakthroughs",
                "automation",
                "ai",
                "nlp",
                "multimodal language model",
            ],
            "creator": [
                "Nvidia just dropped a bombshell: Its new AI model is open, massive, and ready to rival GPT-4",
                "Michael Nuñez",
            ],
            "video_url": None,
            "description": "Nvidia has released NVLM 1.0, a powerful open-source AI model that rivals GPT-4 and Google’s systems, marking a major breakthrough in multimodal language models for vision and text tasks.",
            "content": "ONLY AVAILABLE IN PAID PLANS",
            "pubDate": "2024-10-01 22:58:23",
            "pubDateTZ": "UTC",
            "image_url": "https://venturebeat.com/wp-content/uploads/2024/10/nuneybits_Vector_art_of_a_human_brain_rendered_in_a_semi-transp_907d536c-6a14-4c28-8c81-3d144ea0de3e.webp?w=750",
            "source_id": "venturebeat",
            "source_priority": 24504,
            "source_name": "Venturebeat",
            "source_url": "https://venturebeat.com",
            "source_icon": "https://i.bytvi.com/domain_icons/venturebeat.jpg",
            "language": "english",
            "country": ["united states of america"],
            "category": ["technology", "science"],
            "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
            "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
            "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
            "duplicate": False,
        },
    ],
    "nextPage": "1727823503331520420",
}

# %%
page = None

while True:
    response = api.news_api(q="openai", country="us")
    page = response.get("nextPage", None)
    print(page)
    if not page:
        break

# %% [markdown]
# ### Serp API

# %%
from serpapi import GoogleSearch

# %%
params = {
    "engine": "google_news",
    "q": "pizza",
    "gl": "us",
    "hl": "en",
    "api_key": "SERP_API",
}

search = GoogleSearch(params)
results = search.get_dict()
news_results = results["news_results"]

# %%
print(news_results)
# Out:
# [{'position': 1, 'title': 'News about Pizza Hut, Pizzas', 'stories': [{'position': 1, 'title': 'Pizza Hut is giving away 1 million free pizzas', 'source': {'name': 'Fortune', 'icon': 'https://lh3.googleusercontent.com/tFLb6M9by7fEPdctsE-5e-YDl6ecYOdDGEYTTC5krR3yydg4uRHaSorz2f0hHNyMWSHq20XBMw', 'authors': ['Chris Morris']}, 'link': 'https://fortune.com/2024/10/01/pizza-hut-giving-away-1-million-free-pizzas/', 'thumbnail': 'https://fortune.com/img-assets/wp-content/uploads/2024/10/GettyImages-2147950252-e1727790923474.jpg?w=1440&q=75', 'date': '10/01/2024, 02:23 PM, +0000 UTC'}, {'position': 2, 'title': 'Pizza Hut Is Giving Out 1 Million Free Pizzas to Readers in Honor of Book It! Program’s 40th Anniversary', 'source': {'name': 'PEOPLE', 'icon': 'https://lh3.googleusercontent.com/HL7Lub1zLCotJLKEYDswsz9hiX9BU3JdNAHR5f4vY6J45lPGIGPnwTlmrbIRqmGfnU_Ifb_bZg', 'authors': ['Sabrina Weiss']}, 'link': 'https://people.com/pizza-hut-is-giving-away-1-million-free-pizzas-to-readers-book-it-program
# ...

# %%
import http.client, urllib.parse

conn = http.client.HTTPConnection("api.mediastack.com")

params = urllib.parse.urlencode(
    {
        "access_key": "MEDIASTACK_API_KEY",
        "categories": "-general,-sports",
        "sort": "published_desc",
        "limit": 10,
    }
)

conn.request("GET", "/v1/news?{}".format(params))

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"pagination":{"limit":10,"offset":0,"count":10,"total":10000},"data":[{"author":null,"title":"Do coyotes have puppy dog eyes? New study reveals wild canines share dog\u0027s famous expression","description":"New research from Baylor University reveals that coyotes, like domestic dogs, have the ability to produce the famous \u0022puppy dog eyes\u0022 expression. The study\u2014\u0022Coyotes can do \u0027puppy dog eyes\u0027 too: Comparing interspecific variation in Canis facial expression muscles,\u0022 published in the Royal Society Open Science\u2014challenges the hypothesis that this facial feature evolved exclusively in dogs as a result of domestication.","url":"https:\/\/phys.org\/news\/2024-10-coyotes-puppy-dog-eyes-reveals.html","source":"Phys.org - News And Articles On Science And Technology","image":"https:\/\/scx1.b-cdn.net\/csz\/news\/tmb\/2019\/coyotes.jpg","category":"science","language":"en","country":"us","published_at":"2024-10-02T15:06:38+00:00"},{"author":null,"titl
# ...
